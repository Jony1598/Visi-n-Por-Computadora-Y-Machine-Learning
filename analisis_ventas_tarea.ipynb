# %% [markdown]
# # Análsis de ventas con NumPy
#
# Supongamos que tienes datos de ventas de una tienda en diferentes meses y quieres analizarlos para obtener información clave, como el total de ventas, el promedio de ventas por mes y los meses con mejor desempeño.

# %% [markdown]
# ## Paso 1. Importar NumPy y definir los datos

# %%
import numpy as np

# Datos de ventas por cada mes
ventas = np.array([2300, 2500, 2600, 2100, 2900, 3100, 2800, 2700, 3000, 3300, 3500, 3700])
# Meses del año
meses = np.array(["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
                  "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"])
print(ventas)
print(meses)
# Out:
# [2300 2500 2600 2100 2900 3100 2800 2700 3000 3300 3500 3700]
# ['Enero' 'Febrero' 'Marzo' 'Abril' 'Mayo' 'Junio' 'Julio' 'Agosto'
#  'Septiembre' 'Octubre' 'Noviembre' 'Diciembre']

# %% [markdown]
# ## Paso 2. Análisis de ventas con Numpy
#
# Aplicaremos funciones clave para extraer información útil

# %% [markdown]
# ### 1. Calcular el total y promedio de ventas al año.

# %%
# Obtener el total de las ventas y el promedio, imprimirlas
total = np.sum(ventas)
promedio = np.mean(ventas)
print(f"Total de ventas en el año: ${total}")
print(f"Promedio de ventas en el año ${promedio}")
# Out:
# Total de ventas en el año: $34500
# Promedio de ventas en el año $2875.0

# %% [markdown]
# ### 2. Identificar el mes con más y menos ventas

# %%
# Mes con ventas minimas
minimo = np.min(ventas)
mesmin = np.argmin(ventas)
print(f"Mes con menos ventas: {meses[mesmin]} ${minimo}")
# Mes con ventas maximas
maximo = np.max(ventas)
mesmax = np.argmax(ventas)
print(f"Mes con más ventas: {meses[mesmax]} ${maximo}")
# Out:
# Mes con menos ventas: Abril $2100
# Mes con más ventas: Diciembre $3700

# %% [markdown]
# ### 3. Determinar los meses con ventas superiores al promedio

# %%
# Meses con Ventas mayores al promedio
print("Ventas superiores al promedio")
mesessup = meses[ventas > promedio]
ventassup = ventas[ventas > promedio]
for mes, venta in zip(mesessup, ventassup):
    print(f"{mes}: ${venta}")
# Out:
# Ventas superiores al promedio
# Mayo: $2900
# Junio: $3100
# Septiembre: $3000
# Octubre: $3300
# Noviembre: $3500
# Diciembre: $3700

# %% [markdown]
# ## 4. Aplicar un incremento del 10% en las ventas

# %%
ventas10 = (ventas * 0.10)+ ventas
print("Ventas proyectadas para el proximo año:")
print(ventas10)
# Out:
# Ventas proyectadas para el proximo año:
# [2530. 2750. 2860. 2310. 3190. 3410. 3080. 2970. 3300. 3630. 3850. 4070.]

# %% [markdown]
# ## 5. Gráficar las ventas actuales y el incremento para el próximo año

# %%
# importar la libreria para gráficar matplotlib
import matplotlib.pyplot as plt

# Agregar las etiquetas
plt.figure(figsize = (10,6))
plt.plot(meses, ventas, marker = 'o', color = 'purple', label = '2024')
plt.plot(meses, ventas10, marker = 'o', color = 'blue', label = '2025')
plt.legend(loc='lower right')
plt.title('Tendencia de ventas mensuales', color = 'red', size=12)
plt.xlabel('Mes')
plt.ylabel('Ventas ($)')
plt.grid()
plt.show()

# %% [markdown]
# ## 7. Detectar anomalias con un gráfico de caja (Boxplot)

# %%
# Importamos la libreria seaborn
import seaborn as sea
plt.figure(figsize=(8, 5))
sea.boxplot(y=ventas, color="skyblue")
plt.title("Detección de Anomalías en Ventas (Boxplot)", fontsize=12)
sea.set_style("whitegrid")
plt.xlabel("Ventas ($)")
plt.show()
